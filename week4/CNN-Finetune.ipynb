# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import models
import numpy as np
import matplotlib.pyplot as plt
import os
import timeit
plt.ion()   # interactive mode

# %%
def train(model, device, train_loader, optimizer, criterion, scheduler):    
    EPOCHS = 50
    for epoch in range(EPOCHS):
        losses = []
        running_loss = 0
        for i, inp in enumerate(train_loader):
            inputs, labels = inp
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            losses.append(loss.item())
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            
            if i%100 == 0 and i > 0:
                print(f'Loss [{epoch+1}, {i}](epoch, minibatch): ', running_loss / 100)
                running_loss = 0.0

        avg_loss = sum(losses)/len(losses)
        scheduler.step(avg_loss)

    print('Training Done')

# %%
def test(model, device, test_loader):
    correct = 0
    total = 0

    with torch.no_grad():
        for data in test_loader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)

            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    print('Accuracy on 10,000 test images: ', 100*(correct/total), '%')

# %%
transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, padding=4),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
])

dataset_train = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
dataset_test = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)

train_loader = torch.utils.data.DataLoader(dataset_train, batch_size=64, num_workers=4, pin_memory=True)
test_loader = torch.utils.data.DataLoader(dataset_test, batch_size=64, num_workers=4, pin_memory=True)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

#Additional Info when using cuda
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Tesla V100-PCIE-32GB

# %%
def imshow(inp, title=None):
    """Display image for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.5, 0.5, 0.5])
    std = np.array([0.5, 0.5, 0.5])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated

# Get a batch of training data
inputs, classes = next(iter(train_loader))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)
class_names = dataset_train.classes
imshow(out)

# %% [markdown]
# Fine-tuning

# %%
model= models.resnet18(weights='IMAGENET1K_V1')
num_ftrs = model.fc.in_features

# Here the size of each output sample is set to 10.
# Alternatively, it can be generalized to ``nn.Linear(num_ftrs, len(class_names))``.
model.fc = nn.Linear(num_ftrs, 10)
model = model.to(device)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.1, momentum=0.9, weight_decay=0.0001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, factor = 0.1, patience=5)

# %%
start_time = timeit.default_timer()
train(model, device, train_loader, optimizer, criterion, scheduler)
print(timeit.default_timer() - start_time)
test(model, device, test_loader)
# Out:
# Loss [1, 100](epoch, minibatch):  6.46204567193985
# Loss [1, 200](epoch, minibatch):  2.5403717613220214
# Loss [1, 300](epoch, minibatch):  2.211474393606186
# Loss [1, 400](epoch, minibatch):  2.090234481096268
# Loss [1, 500](epoch, minibatch):  2.0794360291957856
# Loss [1, 600](epoch, minibatch):  2.057819117307663
# Loss [1, 700](epoch, minibatch):  2.044088214635849
# Loss [2, 100](epoch, minibatch):  2.0055235409736634
# Loss [2, 200](epoch, minibatch):  1.9663190352916717
# Loss [2, 300](epoch, minibatch):  1.9440774297714234
# Loss [2, 400](epoch, minibatch):  1.9098462307453155
# Loss [2, 500](epoch, minibatch):  1.8978229415416719
# Loss [2, 600](epoch, minibatch):  1.9040732824802398
# Loss [2, 700](epoch, minibatch):  1.867026505470276
# Loss [3, 100](epoch, minibatch):  1.8600016272068023
# Loss [3, 200](epoch, minibatch):  1.832736257314682
# Loss [3, 300](epoch, minibatch):  1.832352420091629
# Loss [3, 400](epoch, minibatch):  1.7784738993644715
# Loss [3, 500](epoch, minibatch):  1.7810296022891998
# Loss [3, 600](epoch, minibatch):  1.7932104635238648
# Loss [3, 700](epoch, minibatch):  1.7525209951400758
# Loss [4, 100](epoch, minibatch):  1.7522030651569367
# Loss [4, 200](epoch, minibatch):  1.7141691780090331
# Loss [4, 300](epoch, minibatch):  1.6954380869865417
# Loss [4, 400](epoch, minibatch):  1.654456706047058
# Loss [4, 500](epoch, minibatch):  1.6410247564315796
# Loss [4, 600](epoch, minibatch):  1.6658627724647521
# Loss [4, 700](epoch, minibatch):  1.636920564174652
# Loss [5, 100](epoch, minibatch):  1.629312903881073
# Loss [5, 200](epoch, minibatch):  1.6030107820034027
# Loss [5, 300](epoch, minibatch):  1.5930585289001464
# Loss [5, 400](epoch, minibatch):  1.5618438804149628
# Loss [5, 500](epoch, minibatch):  1.5486589407920837
# Loss [5, 600](epoch, minibatch):  1.595356386899948
# Loss [5, 700](epoch, minibatch):  1.554953566789627
# Loss [6, 100](epoch, minibatch):  1.555217695236206
# Loss [6, 200](epoch, minibatch):  1.5341890347003937
# Loss [6, 300](epoch, minibatch):  1.5318173944950104
# Loss [6, 400](epoch, minibatch):  1.5115831732749938
# Loss [6, 500](epoch, minibatch):  1.4987938380241395
# Loss [6, 600](epoch, minibatch):  1.5331338953971863
# Loss [6, 700](epoch, minibatch):  1.4961531043052674
# Loss [7, 100](epoch, minibatch):  1.5208560526371002
# Loss [7, 200](epoch, minibatch):  1.477727255821228
# Loss [7, 300](epoch, minibatch):  1.4746278858184814
# Loss [7, 400](epoch, minibatch):  1.4442263758182525
# Loss [7, 500](epoch, minibatch):  1.4251595187187194
# Loss [7, 600](epoch, minibatch):  1.4602337610721587
# Loss [7, 700](epoch, minibatch):  1.4485321164131164
# Loss [8, 100](epoch, minibatch):  1.4283518981933594
# Loss [8, 200](epoch, minibatch):  1.3972853899002076
# Loss [8, 300](epoch, minibatch):  1.3961806082725525
# Loss [8, 400](epoch, minibatch):  1.3808542627096176
# Loss [8, 500](epoch, minibatch):  1.3497819423675537
# Loss [8, 600](epoch, minibatch):  1.3924049735069275
# Loss [8, 700](epoch, minibatch):  1.381553817987442
# Loss [9, 100](epoch, minibatch):  1.340867069363594
# Loss [9, 200](epoch, minibatch):  1.3265793597698212
# Loss [9, 300](epoch, minibatch):  1.3187894248962402
# Loss [9, 400](epoch, minibatch):  1.2970023369789123
# Loss [9, 500](epoch, minibatch):  1.2896075868606567
# Loss [9, 600](epoch, minibatch):  1.3121826601028443
# Loss [9, 700](epoch, minibatch):  1.29689999461174
# Loss [10, 100](epoch, minibatch):  1.2712282246351243
# Loss [10, 200](epoch, minibatch):  1.2511059796810151
# Loss [10, 300](epoch, minibatch):  1.2543506890535354
# Loss [10, 400](epoch, minibatch):  1.2372475039958954
# Loss [10, 500](epoch, minibatch):  1.2190569829940796
# Loss [10, 600](epoch, minibatch):  1.2542773365974427
# Loss [10, 700](epoch, minibatch):  1.2285505789518356
# Loss [11, 100](epoch, minibatch):  1.1851415663957596
# Loss [11, 200](epoch, minibatch):  1.1982507687807082
# Loss [11, 300](epoch, minibatch):  1.183685976266861
# Loss [11, 400](epoch, minibatch):  1.1704086899757384
# Loss [11, 500](epoch, minibatch):  1.1460393273830414
# Loss [11, 600](epoch, minibatch):  1.1843244588375093
# Loss [11, 700](epoch, minibatch):  1.169677906036377
# Loss [12, 100](epoch, minibatch):  1.1309958577156067
# Loss [12, 200](epoch, minibatch):  1.1342589110136032
# Loss [12, 300](epoch, minibatch):  1.1368039739131928
# Loss [12, 400](epoch, minibatch):  1.1227879059314727
# Loss [12, 500](epoch, minibatch):  1.1006278616189957
# Loss [12, 600](epoch, minibatch):  1.147050360441208
# Loss [12, 700](epoch, minibatch):  1.1172828048467636
# Loss [13, 100](epoch, minibatch):  1.0885537624359132
# Loss [13, 200](epoch, minibatch):  1.0735838985443116
# Loss [13, 300](epoch, minibatch):  1.0754357314109801
# Loss [13, 400](epoch, minibatch):  1.0810092145204544
# Loss [13, 500](epoch, minibatch):  1.0419918555021286
# Loss [13, 600](epoch, minibatch):  1.0837226349115372
# Loss [13, 700](epoch, minibatch):  1.0812654823064805
# Loss [14, 100](epoch, minibatch):  1.051293014883995
# Loss [14, 200](epoch, minibatch):  1.031496332883835
# Loss [14, 300](epoch, minibatch):  1.0467870038747789
# Loss [14, 400](epoch, minibatch):  1.036263684630394
# Loss [14, 500](epoch, minibatch):  1.0205907171964645
# Loss [14, 600](epoch, minibatch):  1.0537362718582153
# Loss [14, 700](epoch, minibatch):  1.0400361448526383
# Loss [15, 100](epoch, minibatch):  1.011121078133583
# Loss [15, 200](epoch, minibatch):  1.0208488857746125
# Loss [15, 300](epoch, minibatch):  1.0003614622354506
# Loss [15, 400](epoch, minibatch):  0.9980547136068344
# Loss [15, 500](epoch, minibatch):  0.9867731928825378
# Loss [15, 600](epoch, minibatch):  1.0254289484024048
# Loss [15, 700](epoch, minibatch):  1.008858333826065
# Loss [16, 100](epoch, minibatch):  0.9753277516365051
# Loss [16, 200](epoch, minibatch):  0.9753913074731827
# Loss [16, 300](epoch, minibatch):  0.9807991248369217
# Loss [16, 400](epoch, minibatch):  0.9659052056074142
# Loss [16, 500](epoch, minibatch):  0.9363982665538788
# Loss [16, 600](epoch, minibatch):  0.9966152721643448
# Loss [16, 700](epoch, minibatch):  0.9531718343496323
# Loss [17, 100](epoch, minibatch):  0.9454355537891388
# Loss [17, 200](epoch, minibatch):  0.9499491673707962
# Loss [17, 300](epoch, minibatch):  0.9452305644750595
# Loss [17, 400](epoch, minibatch):  0.9444251376390457
# Loss [17, 500](epoch, minibatch):  0.9273356503248215
# Loss [17, 600](epoch, minibatch):  0.9685331696271896
# Loss [17, 700](epoch, minibatch):  0.9316669625043869
# Loss [18, 100](epoch, minibatch):  0.9376241654157639
# Loss [18, 200](epoch, minibatch):  0.9364081531763077
# Loss [18, 300](epoch, minibatch):  0.9373210370540619
# Loss [18, 400](epoch, minibatch):  0.9107720947265625
# Loss [18, 500](epoch, minibatch):  0.8876193159818649
# Loss [18, 600](epoch, minibatch):  0.9225183135271072
# Loss [18, 700](epoch, minibatch):  0.9101073026657105
# Loss [19, 100](epoch, minibatch):  0.8926559445261956
# Loss [19, 200](epoch, minibatch):  0.9105114060640335
# Loss [19, 300](epoch, minibatch):  0.8968641579151153
# Loss [19, 400](epoch, minibatch):  0.9039749497175217
# Loss [19, 500](epoch, minibatch):  0.874002355337143
# Loss [19, 600](epoch, minibatch):  0.9170287466049194
# Loss [19, 700](epoch, minibatch):  0.8970518803596497
# Loss [20, 100](epoch, minibatch):  0.8808178848028183
# Loss [20, 200](epoch, minibatch):  0.8714024740457534
# Loss [20, 300](epoch, minibatch):  0.8714706927537919
# Loss [20, 400](epoch, minibatch):  0.8715297138690948
# Loss [20, 500](epoch, minibatch):  0.8635668557882309
# Loss [20, 600](epoch, minibatch):  0.8935189217329025
# Loss [20, 700](epoch, minibatch):  0.8738429880142212
# Loss [21, 100](epoch, minibatch):  0.8655575132369995
# Loss [21, 200](epoch, minibatch):  0.8640256375074387
# Loss [21, 300](epoch, minibatch):  0.8626752412319183
# Loss [21, 400](epoch, minibatch):  0.8564186203479767
# Loss [21, 500](epoch, minibatch):  0.8322313970327377
# Loss [21, 600](epoch, minibatch):  0.8825406378507614
# Loss [21, 700](epoch, minibatch):  0.8409697717428207
# Loss [22, 100](epoch, minibatch):  0.8447115877270699
# Loss [22, 200](epoch, minibatch):  0.855392142534256
# Loss [22, 300](epoch, minibatch):  0.8344317364692688
# Loss [22, 400](epoch, minibatch):  0.8376934498548507
# Loss [22, 500](epoch, minibatch):  0.8180669343471527
# Loss [22, 600](epoch, minibatch):  0.8522899293899536
# Loss [22, 700](epoch, minibatch):  0.8279913568496704
# Loss [23, 100](epoch, minibatch):  0.824983617067337
# Loss [23, 200](epoch, minibatch):  0.813952616751194
# Loss [23, 300](epoch, minibatch):  0.818823266029358
# Loss [23, 400](epoch, minibatch):  0.8093227046728134
# Loss [23, 500](epoch, minibatch):  0.8127999097108841
# Loss [23, 600](epoch, minibatch):  0.8450015926361084
# Loss [23, 700](epoch, minibatch):  0.8017463624477387
# Loss [24, 100](epoch, minibatch):  0.8058020389080047
# Loss [24, 200](epoch, minibatch):  0.8008233791589737
# Loss [24, 300](epoch, minibatch):  0.8023670548200608
# Loss [24, 400](epoch, minibatch):  0.8066059279441834
# Loss [24, 500](epoch, minibatch):  0.7946959573030472
# Loss [24, 600](epoch, minibatch):  0.8246501988172531
# Loss [24, 700](epoch, minibatch):  0.7758099481463432
# Loss [25, 100](epoch, minibatch):  0.7854315868020058
# Loss [25, 200](epoch, minibatch):  0.783772155046463
# Loss [25, 300](epoch, minibatch):  0.7769117164611816
# Loss [25, 400](epoch, minibatch):  0.7784667375683785
# Loss [25, 500](epoch, minibatch):  0.7686850157380104
# Loss [25, 600](epoch, minibatch):  0.8151071661710739
# Loss [25, 700](epoch, minibatch):  0.7766505530476571
# Loss [26, 100](epoch, minibatch):  0.7748270547389984
# Loss [26, 200](epoch, minibatch):  0.776406601369381
# Loss [26, 300](epoch, minibatch):  0.7715257638692856
# Loss [26, 400](epoch, minibatch):  0.7795893153548241
# Loss [26, 500](epoch, minibatch):  0.7688677591085434
# Loss [26, 600](epoch, minibatch):  0.7962790885567665
# Loss [26, 700](epoch, minibatch):  0.7598126417398453
# Loss [27, 100](epoch, minibatch):  0.7573734596371651
# Loss [27, 200](epoch, minibatch):  0.7550251150131225
# Loss [27, 300](epoch, minibatch):  0.7622704404592514
# Loss [27, 400](epoch, minibatch):  0.7701086431741715
# Loss [27, 500](epoch, minibatch):  0.7382390287518501
# Loss [27, 600](epoch, minibatch):  0.7846706077456475
# Loss [27, 700](epoch, minibatch):  0.7441501548886299
# Loss [28, 100](epoch, minibatch):  0.7532543733716011
# Loss [28, 200](epoch, minibatch):  0.7483660495281219
# Loss [28, 300](epoch, minibatch):  0.7651648259162903
# Loss [28, 400](epoch, minibatch):  0.737627229988575
# Loss [28, 500](epoch, minibatch):  0.7275618404150009
# Loss [28, 600](epoch, minibatch):  0.7802065894007683
# Loss [28, 700](epoch, minibatch):  0.7403097230196
# Loss [29, 100](epoch, minibatch):  0.7283816275000572
# Loss [29, 200](epoch, minibatch):  0.7344204908609391
# Loss [29, 300](epoch, minibatch):  0.7473466059565544
# Loss [29, 400](epoch, minibatch):  0.7396134513616562
# Loss [29, 500](epoch, minibatch):  0.7426081287860871
# Loss [29, 600](epoch, minibatch):  0.7570772412419319
# Loss [29, 700](epoch, minibatch):  0.7144435912370681
# Loss [30, 100](epoch, minibatch):  0.7141074749827385
# Loss [30, 200](epoch, minibatch):  0.718271227478981
# Loss [30, 300](epoch, minibatch):  0.7289573442935944
# Loss [30, 400](epoch, minibatch):  0.749710144996643
# Loss [30, 500](epoch, minibatch):  0.7418728092312813
# Loss [30, 600](epoch, minibatch):  0.7500813975930214
# Loss [30, 700](epoch, minibatch):  0.7146379107236862
# Loss [31, 100](epoch, minibatch):  0.72014897108078
# Loss [31, 200](epoch, minibatch):  0.7228979623317718
# Loss [31, 300](epoch, minibatch):  0.7143128544092179
# Loss [31, 400](epoch, minibatch):  0.7228690806031227
# Loss [31, 500](epoch, minibatch):  0.7078014126420021
# Loss [31, 600](epoch, minibatch):  0.7373491188883782
# Loss [31, 700](epoch, minibatch):  0.7302380448579788
# Loss [32, 100](epoch, minibatch):  0.7121663457155227
# Loss [32, 200](epoch, minibatch):  0.7117647877335549
# Loss [32, 300](epoch, minibatch):  0.7097521832585335
# Loss [32, 400](epoch, minibatch):  0.7304478821158409
# Loss [32, 500](epoch, minibatch):  0.693344612121582
# Loss [32, 600](epoch, minibatch):  0.7317357367277145
# Loss [32, 700](epoch, minibatch):  0.71061108648777
# Loss [33, 100](epoch, minibatch):  0.7045680555701256
# Loss [33, 200](epoch, minibatch):  0.699533309340477
# Loss [33, 300](epoch, minibatch):  0.6975629594922066
# Loss [33, 400](epoch, minibatch):  0.701526158452034
# Loss [33, 500](epoch, minibatch):  0.7029050490260125
# Loss [33, 600](epoch, minibatch):  0.727865689098835
# Loss [33, 700](epoch, minibatch):  0.6964686939120293
# Loss [34, 100](epoch, minibatch):  0.6911553242802619
# Loss [34, 200](epoch, minibatch):  0.6806773987412452
# Loss [34, 300](epoch, minibatch):  0.6853529101610184
# Loss [34, 400](epoch, minibatch):  0.6931337106227875
# Loss [34, 500](epoch, minibatch):  0.6905050331354141
# Loss [34, 600](epoch, minibatch):  0.723229610323906
# Loss [34, 700](epoch, minibatch):  0.6922237628698349
# Loss [35, 100](epoch, minibatch):  0.6855909952521324
# Loss [35, 200](epoch, minibatch):  0.6833309930562973
# Loss [35, 300](epoch, minibatch):  0.6975209665298462
# Loss [35, 400](epoch, minibatch):  0.6729017975926399
# Loss [35, 500](epoch, minibatch):  0.6992285111546517
# Loss [35, 600](epoch, minibatch):  0.7226037490367889
# Loss [35, 700](epoch, minibatch):  0.6719921433925629
# Loss [36, 100](epoch, minibatch):  0.6673505556583404
# Loss [36, 200](epoch, minibatch):  0.6741333493590355
# Loss [36, 300](epoch, minibatch):  0.6750792372226715
# Loss [36, 400](epoch, minibatch):  0.6845938739180565
# Loss [36, 500](epoch, minibatch):  0.6661274737119675
# Loss [36, 600](epoch, minibatch):  0.7120008757710456
# Loss [36, 700](epoch, minibatch):  0.6686786743998527
# Loss [37, 100](epoch, minibatch):  0.6775749891996383
# Loss [37, 200](epoch, minibatch):  0.6853663113713264
# Loss [37, 300](epoch, minibatch):  0.6631873223185539
# Loss [37, 400](epoch, minibatch):  0.6731931978464126
# Loss [37, 500](epoch, minibatch):  0.6577277418971061
# Loss [37, 600](epoch, minibatch):  0.7013225010037423
# Loss [37, 700](epoch, minibatch):  0.6820490887761116
# Loss [38, 100](epoch, minibatch):  0.6680507466197014
# Loss [38, 200](epoch, minibatch):  0.6703244414925575
# Loss [38, 300](epoch, minibatch):  0.6646380642056465
# Loss [38, 400](epoch, minibatch):  0.6687555208802223
# Loss [38, 500](epoch, minibatch):  0.6688425344228744
# Loss [38, 600](epoch, minibatch):  0.6941824096441269
# Loss [38, 700](epoch, minibatch):  0.6606449827551841
# Loss [39, 100](epoch, minibatch):  0.646331827044487
# Loss [39, 200](epoch, minibatch):  0.658226872086525
# Loss [39, 300](epoch, minibatch):  0.6691619202494621
# Loss [39, 400](epoch, minibatch):  0.6618727532029152
# Loss [39, 500](epoch, minibatch):  0.6523603263497353
# Loss [39, 600](epoch, minibatch):  0.7001551374793052
# Loss [39, 700](epoch, minibatch):  0.6684318837523461
# Loss [40, 100](epoch, minibatch):  0.6712436664104462
# Loss [40, 200](epoch, minibatch):  0.6566516596078873
# Loss [40, 300](epoch, minibatch):  0.6679739037156105
# Loss [40, 400](epoch, minibatch):  0.674184399843216
# Loss [40, 500](epoch, minibatch):  0.6467656853795052
# Loss [40, 600](epoch, minibatch):  0.682767168879509
# Loss [40, 700](epoch, minibatch):  0.6476246407628059
# Loss [41, 100](epoch, minibatch):  0.6507542759180069
# Loss [41, 200](epoch, minibatch):  0.6580507835745811
# Loss [41, 300](epoch, minibatch):  0.6458963146805763
# Loss [41, 400](epoch, minibatch):  0.6336978968977928
# Loss [41, 500](epoch, minibatch):  0.6496007627248764
# Loss [41, 600](epoch, minibatch):  0.6653840026259422
# Loss [41, 700](epoch, minibatch):  0.6429581156373024
# Loss [42, 100](epoch, minibatch):  0.6606130030751228
# Loss [42, 200](epoch, minibatch):  0.6483827465772629
# Loss [42, 300](epoch, minibatch):  0.6383170789480209
# Loss [42, 400](epoch, minibatch):  0.6346647563576698
# Loss [42, 500](epoch, minibatch):  0.6314257273077964
# Loss [42, 600](epoch, minibatch):  0.6784789806604385
# Loss [42, 700](epoch, minibatch):  0.6366323086619378
# Loss [43, 100](epoch, minibatch):  0.6221872264146805
# Loss [43, 200](epoch, minibatch):  0.6341880863904953
# Loss [43, 300](epoch, minibatch):  0.6367414447665215
# Loss [43, 400](epoch, minibatch):  0.6459397479891777
# Loss [43, 500](epoch, minibatch):  0.6209378704428673
# Loss [43, 600](epoch, minibatch):  0.6759788039326667
# Loss [43, 700](epoch, minibatch):  0.6271701052784919
# Loss [44, 100](epoch, minibatch):  0.6331750491261482
# Loss [44, 200](epoch, minibatch):  0.6413393330574035
# Loss [44, 300](epoch, minibatch):  0.6440620163083076
# Loss [44, 400](epoch, minibatch):  0.620988141298294
# Loss [44, 500](epoch, minibatch):  0.6196827140450477
# Loss [44, 600](epoch, minibatch):  0.6627761051058769
# Loss [44, 700](epoch, minibatch):  0.6252797907590866
# Loss [45, 100](epoch, minibatch):  0.6331814196705818
# Loss [45, 200](epoch, minibatch):  0.63010003387928
# Loss [45, 300](epoch, minibatch):  0.6249589571356773
# Loss [45, 400](epoch, minibatch):  0.6151982036232948
# Loss [45, 500](epoch, minibatch):  0.6083202004432678
# Loss [45, 600](epoch, minibatch):  0.6659088137745858
# Loss [45, 700](epoch, minibatch):  0.618424496948719
# Loss [46, 100](epoch, minibatch):  0.634143995642662
# Loss [46, 200](epoch, minibatch):  0.6420549753308297
# Loss [46, 300](epoch, minibatch):  0.6301957574486733
# Loss [46, 400](epoch, minibatch):  0.6310112607479096
# Loss [46, 500](epoch, minibatch):  0.6280327671766281
# Loss [46, 600](epoch, minibatch):  0.6583513030409813
# Loss [46, 700](epoch, minibatch):  0.6274615317583084
# Loss [47, 100](epoch, minibatch):  0.6145175325870514
# Loss [47, 200](epoch, minibatch):  0.6190679934620857
# Loss [47, 300](epoch, minibatch):  0.6319134309887886
# Loss [47, 400](epoch, minibatch):  0.6082937854528427
# Loss [47, 500](epoch, minibatch):  0.6296524029970169
# Loss [47, 600](epoch, minibatch):  0.6438165917992592
# Loss [47, 700](epoch, minibatch):  0.6071800523996354
# Loss [48, 100](epoch, minibatch):  0.6169223979115486
# Loss [48, 200](epoch, minibatch):  0.6299632418155671
# Loss [48, 300](epoch, minibatch):  0.617616575062275
# Loss [48, 400](epoch, minibatch):  0.6428191554546356
# Loss [48, 500](epoch, minibatch):  0.5879549506306648
# Loss [48, 600](epoch, minibatch):  0.6342459633946419
# Loss [48, 700](epoch, minibatch):  0.6162927608191967
# Loss [49, 100](epoch, minibatch):  0.6067313519120217
# Loss [49, 200](epoch, minibatch):  0.6149479556083679
# Loss [49, 300](epoch, minibatch):  0.6105329662561416
# Loss [49, 400](epoch, minibatch):  0.6298039323091507
# Loss [49, 500](epoch, minibatch):  0.6176067233085633
# Loss [49, 600](epoch, minibatch):  0.6432171505689621
# Loss [49, 700](epoch, minibatch):  0.613981599509716
# Loss [50, 100](epoch, minibatch):  0.6232059556245804
# Loss [50, 200](epoch, minibatch):  0.620736712217331
# Loss [50, 300](epoch, minibatch):  0.599229750931263
# Loss [50, 400](epoch, minibatch):  0.6141001483798028
# Loss [50, 500](epoch, minibatch):  0.6070795023441314
# Loss [50, 600](epoch, minibatch):  0.6567573836445808
# Loss [50, 700](epoch, minibatch):  0.5934375742077828
# Training Done
# 814.7252148203552
# Accuracy on 10,000 test images:  76.67 %
